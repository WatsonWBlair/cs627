# %%
import torch
from module import ImageVAE

# %%
inputDim = 28**2
x = torch.rand(4, inputDim)
vae = ImageVAE(input_dim=inputDim)
x_reconstructed, mu, sigma = vae(x)
print(x_reconstructed.shape)
print(mu.shape)
print(sigma.shape)
# Out:
# torch.Size([4, 784])
# torch.Size([4, 20])
# torch.Size([4, 20])
