# %%
# %pip install --upgrade pip
# %pip install fairseq2 sonar-space
# %pip install libsndfile
# %pip install transformers datasets evaluate accelerate trl
# %pip install mteb sentence-transformers
# %pip install tensor
# Out:
# Requirement already satisfied: transformers in c:\users\watso\anaconda3\lib\site-packages (4.57.1)
# Requirement already satisfied: datasets in c:\users\watso\anaconda3\lib\site-packages (4.4.1)
# Requirement already satisfied: evaluate in c:\users\watso\anaconda3\lib\site-packages (0.4.6)
# Requirement already satisfied: accelerate in c:\users\watso\anaconda3\lib\site-packages (1.11.0)
# Requirement already satisfied: trl in c:\users\watso\anaconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: filelock in c:\users\watso\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\watso\anaconda3\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\watso\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\watso\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\watso\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\watso\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\watso\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\watso\anaconda3\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\watso\anaconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\watso\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\watso\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\watso\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\watso\anaconda3\lib\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\watso\anaconda3\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\watso\anaconda3\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\watso\anaconda3\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in c:\users\watso\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\watso\anaconda3\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\watso\anaconda3\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.11.10)
# Requirement already satisfied: anyio in c:\users\watso\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (4.7.0)
# Requirement already satisfied: certifi in c:\users\watso\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\watso\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\watso\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\watso\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: psutil in c:\users\watso\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=2.0.0 in c:\users\watso\anaconda3\lib\site-packages (from accelerate) (2.9.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\watso\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\watso\anaconda3\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\watso\anaconda3\lib\site-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\watso\anaconda3\lib\site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\watso\anaconda3\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\watso\anaconda3\lib\site-packages (from torch>=2.0.0->accelerate) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\watso\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\watso\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\watso\anaconda3\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\watso\anaconda3\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\watso\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\watso\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\watso\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\watso\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mteb in c:\users\watso\anaconda3\lib\site-packages (2.1.17)
# Requirement already satisfied: sentence-transformers in c:\users\watso\anaconda3\lib\site-packages (5.1.2)
# Requirement already satisfied: datasets>=2.19.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (4.4.1)
# Requirement already satisfied: numpy<3.0.0,>=1.0.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (2.1.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (1.6.1)
# Requirement already satisfied: scipy>=0.0.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (1.15.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (4.12.2)
# Requirement already satisfied: torch>1.0.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (2.9.1)
# Requirement already satisfied: tqdm>1.0.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (4.67.1)
# Requirement already satisfied: rich>=0.0.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (13.9.4)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.6 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (0.5.10)
# Requirement already satisfied: pydantic>=2.0.0 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (2.10.3)
# Requirement already satisfied: polars>=0.20.22 in c:\users\watso\anaconda3\lib\site-packages (from mteb) (1.35.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\watso\anaconda3\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\watso\anaconda3\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\users\watso\anaconda3\lib\site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: filelock in c:\users\watso\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\watso\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\watso\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\watso\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\watso\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\watso\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\watso\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\watso\anaconda3\lib\site-packages (from datasets>=2.19.0->mteb) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\watso\anaconda3\lib\site-packages (from datasets>=2.19.0->mteb) (0.4.0)
# Requirement already satisfied: pandas in c:\users\watso\anaconda3\lib\site-packages (from datasets>=2.19.0->mteb) (2.2.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\watso\anaconda3\lib\site-packages (from datasets>=2.19.0->mteb) (0.28.1)
# Requirement already satisfied: xxhash in c:\users\watso\anaconda3\lib\site-packages (from datasets>=2.19.0->mteb) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\watso\anaconda3\lib\site-packages (from datasets>=2.19.0->mteb) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\watso\anaconda3\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (3.11.10)
# Requirement already satisfied: anyio in c:\users\watso\anaconda3\lib\site-packages (from httpx<1.0.0->datasets>=2.19.0->mteb) (4.7.0)
# Requirement already satisfied: certifi in c:\users\watso\anaconda3\lib\site-packages (from httpx<1.0.0->datasets>=2.19.0->mteb) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\watso\anaconda3\lib\site-packages (from httpx<1.0.0->datasets>=2.19.0->mteb) (1.0.9)
# Requirement already satisfied: idna in c:\users\watso\anaconda3\lib\site-packages (from httpx<1.0.0->datasets>=2.19.0->mteb) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\watso\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.19.0->mteb) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\watso\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (1.18.0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in c:\users\watso\anaconda3\lib\site-packages (from polars>=0.20.22->mteb) (1.35.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\watso\anaconda3\lib\site-packages (from pydantic>=2.0.0->mteb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\watso\anaconda3\lib\site-packages (from pydantic>=2.0.0->mteb) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\watso\anaconda3\lib\site-packages (from requests>=2.26.0->mteb) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\watso\anaconda3\lib\site-packages (from requests>=2.26.0->mteb) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\watso\anaconda3\lib\site-packages (from rich>=0.0.0->mteb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\watso\anaconda3\lib\site-packages (from rich>=0.0.0->mteb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\watso\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=0.0.0->mteb) (0.1.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\watso\anaconda3\lib\site-packages (from scikit-learn>=1.4.0->mteb) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\watso\anaconda3\lib\site-packages (from scikit-learn>=1.4.0->mteb) (3.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\watso\anaconda3\lib\site-packages (from torch>1.0.0->mteb) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\watso\anaconda3\lib\site-packages (from torch>1.0.0->mteb) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\watso\anaconda3\lib\site-packages (from torch>1.0.0->mteb) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\watso\anaconda3\lib\site-packages (from torch>1.0.0->mteb) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\watso\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>1.0.0->mteb) (1.3.0)
# Requirement already satisfied: colorama in c:\users\watso\anaconda3\lib\site-packages (from tqdm>1.0.0->mteb) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\watso\anaconda3\lib\site-packages (from anyio->httpx<1.0.0->datasets>=2.19.0->mteb) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\watso\anaconda3\lib\site-packages (from jinja2->torch>1.0.0->mteb) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\watso\anaconda3\lib\site-packages (from pandas->datasets>=2.19.0->mteb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\watso\anaconda3\lib\site-packages (from pandas->datasets>=2.19.0->mteb) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\watso\anaconda3\lib\site-packages (from pandas->datasets>=2.19.0->mteb) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\watso\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.19.0->mteb) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensor in c:\users\watso\anaconda3\lib\site-packages (0.3.6)
# Requirement already satisfied: Twisted in c:\users\watso\anaconda3\lib\site-packages (from tensor) (24.11.0)
# Requirement already satisfied: PyYaml in c:\users\watso\anaconda3\lib\site-packages (from tensor) (6.0.2)
# Requirement already satisfied: protobuf in c:\users\watso\anaconda3\lib\site-packages (from tensor) (5.29.3)
# Requirement already satisfied: construct in c:\users\watso\anaconda3\lib\site-packages (from tensor) (2.10.70)
# Requirement already satisfied: pysnmp in c:\users\watso\anaconda3\lib\site-packages (from tensor) (7.1.22)
# Requirement already satisfied: pyasn1!=0.5.0,>=0.4.8 in c:\users\watso\anaconda3\lib\site-packages (from pysnmp->tensor) (0.4.8)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\watso\anaconda3\lib\site-packages (from Twisted->tensor) (24.3.0)
# Requirement already satisfied: automat>=24.8.0 in c:\users\watso\anaconda3\lib\site-packages (from Twisted->tensor) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in c:\users\watso\anaconda3\lib\site-packages (from Twisted->tensor) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\watso\anaconda3\lib\site-packages (from Twisted->tensor) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in c:\users\watso\anaconda3\lib\site-packages (from Twisted->tensor) (24.7.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\watso\anaconda3\lib\site-packages (from Twisted->tensor) (4.12.2)
# Requirement already satisfied: zope-interface>=5 in c:\users\watso\anaconda3\lib\site-packages (from Twisted->tensor) (7.1.1)
# Requirement already satisfied: idna>=2.5 in c:\users\watso\anaconda3\lib\site-packages (from hyperlink>=17.1.1->Twisted->tensor) (3.7)
# Requirement already satisfied: setuptools>=61.0 in c:\users\watso\anaconda3\lib\site-packages (from incremental>=24.7.0->Twisted->tensor) (72.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from Training.encoder_trainers import Contrast

from Training.Data_Wrangling.text import load_local

from Encoders.img_2_vec import Image_to_Vec
from Encoders.text_2_vec import Text_to_Vec

from datasets import load_dataset

# %%
# try:
#     sts_dataset = load_local('SEED_ENCODED_MTEB')
#     print(f"\nSuccessfully loaded 'mteb/stsbenchmark-sts' (English) Test set. Number of examples: {len(sts_dataset)}")
# except Exception as e:
#     print(f"\nCould not load mteb/stsbenchmark-sts dataset: {e}")

# checkpoint = 'facebook/bart-base'
# tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# sts_dataset = load_dataset("mteb/stsbenchmark-sts", split="train")

dataset = load_dataset("AbstractTTS/IEMOCAP", split='train')

# %%
print(dataset)
# Out:
# Dataset({
#     features: ['file', 'audio', 'frustrated', 'angry', 'sad', 'disgust', 'excited', 'fear', 'neutral', 'surprise', 'happy', 'EmoAct', 'EmoVal', 'EmoDom', 'gender', 'transcription', 'major_emotion', 'speaking_rate', 'pitch_mean', 'pitch_std', 'rms', 'relative_db'],
#     num_rows: 10039
# })

# %%
from transformers import AutoTokenizer, DataCollatorWithPadding

raw_datasets = load_local("Training/Data_Wrangling/SEED_ENC_MTEB_DATASET")
checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)


def tokenize_function(example):
    return tokenizer(example["sentence1"], example["sentence2"], truncation=True)


tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
# https://docs.pytorch.org/docs/stable/generated/torch.nn.TripletMarginLoss.html
