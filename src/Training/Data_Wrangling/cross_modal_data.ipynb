# %%
# %pip install torch torchcodec
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Cross modally labeled data is critical for training.

# %% [markdown]
# Combining Cross Modality Encoders to jointly inform a semantic-vector space:
# Usecase Multi-Modal Chatbot: Video, Audio in Text out.
#
# Use Encoder Stacks to build a complete semantic representation of the input:
#
# Audio Emotion Labeling
# AbstractTTS/IEMOCAP -> Emotionally Labelied audio files. Available on Hugging Face - Audio Emotional Encoder
# Toronto emotional Speech set (TESS) - https://www.kaggle.com/datasets/ejlok1/toronto-emotional-speech-set-tess - Audio Emotional Encoder
#
# Speech to Text
# openslr/librispeech_asr -> Textually labeled speech data

# %%
from datasets import load_dataset, Audio

# ASR with Emotion Detection
dataset = load_dataset("AbstractTTS/IEMOCAP", split='train')
dataset = dataset.cast_column("audio", Audio(sampling_rate=16000))

# %%
print(dataset.column_names)
print(dataset[0])
# Out:
# ['file', 'audio', 'frustrated', 'angry', 'sad', 'disgust', 'excited', 'fear', 'neutral', 'surprise', 'happy', 'EmoAct', 'EmoVal', 'EmoDom', 'gender', 'transcription', 'major_emotion', 'speaking_rate', 'pitch_mean', 'pitch_std', 'rms', 'relative_db']
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 2
#       1 print(dataset.column_names)
# ----> 2 print(dataset[0])
#
# File c:\Users\watso\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:2876, in Dataset.__getitem__(self, key)
#    2874     if self._format_type is None or self._format_type not in ("arrow", "pandas", "polars"):
#    2875         return Column(self, key)
# -> 2876 return self._getitem(key)
#
# File c:\Users\watso\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:2858, in Dataset._getitem(self, key, **kwargs)
# ...

# %%
# Prepair data for text_2_vec
#

# %%
# Prepair data for wav_2_vec
#
