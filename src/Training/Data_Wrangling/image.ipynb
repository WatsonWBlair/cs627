# %%
# Imports

# %%
# Import and Process Image Contrastive Sets for Encoder Training

# Phase 1: Simpleist Image Usecase (reconstruction is iffy)
# Query point is a small image with minimal complexity
# Positive point is short sentance extracted from image using image->text encoder
#   - the vector should caputre obvious details: color, large actions, ect...
# Negative point is generated by encoding positive point to semantic space and rotating vector.
#   - Training Stratagy should start with diometricly opposed vectors and progress to finer distinctions.

# Phase 2: Medium Complexity(moderate reconstruction success)
# Query point is a medium-sized image
# Positive point is medium description of image extracted from image using image->text encoder
#   - the vector should capture medium detail: movement, composition, ect... 
# Negative Point is rotation of positive point semantic vector.

# Phase 3: Advanced Complexity(accurate reconstruction)
# Query point is size to be reasonable for front-facing phone camera.
# Positive point is full description of image extracted using image->text encoder
#   - the vector should capture fine detail: textures, relationships, composition, ect...
# 

# Phase 4: Summed Encoder vectors

# %%
# Import and Process Image SEt for Decoder Training
# Decoder training follows Encoder traingng and uses the same phased approach to iterativly grow complexity.

# Because Decoder Training does not require triplits, we can use the raw images used in Phases 1-3 of Encoder Training.
