# %%
from Adapter import Adapter

# %%
# Instantiate, save, and load weights
model = Adapter('testing')
model.save()
model.load()

# %%
# Load Data

# %%
# Define Training Arguments
from transformers import TrainingArguments

training_args = TrainingArguments(output_dir="./results",
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    logging_dir="./logs",
    logging_steps=100,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
)

# %%
from transformers import Trainer

model = Adapter('Testing')

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=your_train_dataset, # Replace with your actual dataset
    eval_dataset=your_eval_dataset,   # Replace with your actual dataset
    # compute_metrics=your_compute_metrics_function, # Optional
)
